# %% [markdown]
# <center><font size=20>Health Insurance Premium Prediction</center></font>
#
# <center><p float="center">
#   <img src="https://i.imgur.com/xmmHDWm.jpeg" alt="DALL-E-2025-02-27-15-47-37-An-international-outdoor-DTH-store-labeled-AUTHORIZED-DTH-OUTLET-with-a-m"width=720></a>

# %% [markdown]
# # 🏥 Health Insurance Premium Prediction
#
# ---
#
# # 1. 🎯 Project Objective
#
# ## Main Objective
#
# The primary objective of this project is to develop a `**Machine Learning  Model**` that can accurately predict a person's `**Health Insurance Premium (Charges)**` using their personal and health-related information.
#
# ### Why is this project needed?
#
# Insurance companies receive thousands of customer applications every day. Every applicant has different characteristics
#
# If insurance premiums are calculated manually:
#
# - It requires a significant amount of time.
# - Human errors may occur.
# - Pricing may not be consistent across customers.
# - Risk assessment becomes difficult.
#
# Machine Learning automates this entire process by learning patterns from historical data and provides **fast, accurate, fair, and data-driven premium estimation.**
#
# ---
#
# # 2. 📌 Problem Statement
#
# ### Problem Statement
#
# Predict the **Health Insurance Charges (Premium)** based on individual characteristics such as:
#
# - Age
# - Sex
# - BMI (Body Mass Index)
# - Number of Children
# - Smoking Status
# - Region
#
# ### Simple Explanation
#
# Suppose a new customer visits an insurance company to purchase health insurance.
#
# The company needs to determine:
#
# > **"How much insurance premium should be charged for this customer?"**
#
# Instead of manually calculating the premium using fixed rules, we build a Machine Learning model that automatically predicts the expected insurance charges based on customer information.
#
# ---
#
# # 3. 💼 Business Problem
#
# Insurance companies face several real-world challenges.
#
# ### Problem 1: Incorrect Pricing
#
# ### Problem 2: Manual Premium Calculation
#
# ### Problem 3: Risk Identification
#
#
# ## Solution
#
# Develop a Machine Learning Regression Model that predicts health insurance charges using customer demographic and health-related information.
#
# This helps insurance companies make better pricing decisions while reducing manual effort.
#
# ---
#
# # 4. 🎯 Business Objective
#
# The project helps insurance companies to:
#
# - Predict health insurance premiums accurately.
# - Reduce pricing errors.
# - Identify the major factors affecting insurance cost.
# - Improve profitability.
# - Provide fair and consistent pricing.
# - Automate premium calculation.
# - Reduce manual effort.
# - Make faster and data-driven business decisions.
# - Improve customer satisfaction through accurate premium estimation.
#
# ---

# %% [markdown]
# <center>
#   <img src="https://drive.google.com/uc?export=view&id=1wwHyfyrGeTKdVEf70-PSOzbgHe1B3mBR" alt="Description">
# </center>

# %% [markdown]
# # 🤖 Machine Learning Objective
#
# The Machine Learning model learns hidden relationships between customer information and insurance charges.
#
# ```
# Input Features
#       │
#       ▼
# Machine Learning Algorithm
# (Learns Hidden Mathematical Relationships)
#       │
#       ▼
# Predicted Insurance Charges
# ```
#
# The model learns patterns like:
#
# ```
#         X
# Age
# BMI
# Gender
# Children
# Smoking Status
# Region
#         │
#         ▼
#         Y
# Predicted Insurance Charges
# ```
#
# After training, the model can estimate insurance premiums for completely new customers whose charges are unknown.
#
# ---
#
# # 6. 🧠 Type of Machine Learning
#
# ## Supervised Learning
#
# This project belongs to **Supervised Machine Learning** because the dataset already contains both:
#
# - Input Features (X)
# - Correct Output (Y)
#
# Example:
#
# | Age | BMI | Smoker | Charges |
# |-----|-----|---------|---------|
# |23|28|No|5000|
# |45|31|Yes|28000|
#
# During training, the model learns the relationship between the inputs and their corresponding insurance charges.
#
# Later, it predicts charges for unseen customers.
#
# ---
#
# ## Regression Problem
#
# The target variable is:
#
# **Charges**
#
# Charges are continuous numerical values.
#
# Example:
#
# ```
# 15467.89
#
# 22350.42
#
# 39876.11
# ```
#
# Since the output is a continuous number rather than categories like Yes/No or Male/Female, this project is a **Regression Problem**.
#
# ---
#
# # 7. 📊 Dataset Information
#
# The dataset contains information about health insurance customers.
#
# ### Dataset Summary
#
# - Total Records : **1338**
# - Total Features : **7 Columns**
#
# The dataset contains both numerical and categorical features along with the insurance charges.
#
# ---
#
# # 8. 📥 Input Features
#
# The Machine Learning model uses the following input features for prediction.
#
# | Feature | Description | Data Type |
# |----------|-------------|-----------|
# | Age | Customer Age | Numerical |
# | Sex | Male / Female | Categorical |
# | BMI | Body Mass Index | Numerical |
# | Children | Number of Dependents | Numerical |
# | Smoker | Smoking Status (Yes/No) | Categorical |
# | Region | Residential Region | Categorical |
#
# These features represent the customer's personal and health-related information that influences insurance charges.
#
# ---
#
# # 9. 📤 Expected Output
#
# The model predicts the following output:
#
# ## **Insurance Charges (Premium Amount)**
#
# Example:
#
# ```
# Predicted Insurance Premium
#
# ₹15,500
#
# or
#
# $15,500
# ```
#
# (depending on the currency used in the dataset)
#
# The predicted insurance charge represents the estimated premium that should be charged for a customer based on their demographic and health-related information.
#
# ---

# %% [markdown]
# ## Data Description

# %% [markdown]
# The dataset consists of several key attributes:
#
# - **Age**: Numerical value representing the age of the insured individual.
# - **Sex**: Categorical variable indicating gender (male or female).
# - **BMI**: Numerical value reflecting the Body Mass Index, a measure of body fat based on height and weight.
#
#     The standard healthy BMI range for adults is 18.5 to 24.9.
# - **Children**: Numerical value representing the number of dependent children covered by the insurance policy.
# - **Smoker**: Categorical variable indicating whether the individual is a smoker (yes or no).
# - **Region**: Categorical variable that identifies the geographic area of the insured (southwest, southeast, northwest, northeast).
# - **Charges**: Numerical value indicating the annual insurance premium (in USD) incurred by the policyholder.
#
# This dataset contains a diverse range of cases, facilitating the modeling of different demographic and health profiles to predict insurance charges effectively.

# %% [markdown]
# ## Flow Overview
#
# 1. Analyze the data
# 2. Visualize patterns in the data
# 3. Preprocess the data
# 4. Build a Linear regression Model
# 5. Evaluate the model's performance
# 6. Predicting for unseen Data
# </font>

# %% [markdown]
# # **Installing and Importing Necessary Libraries**

# %% [markdown]
# ## Import libraries

# %%
# Import libraries for reading and manipulating data
import pandas as pd
# Import library for numerical operations
import numpy as np

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Linear Regression model
from sklearn.linear_model import LinearRegression

# Import utilities for performance evaluation
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Import utilities for data preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %% [markdown]
# # **Loading the Data**

# %% [markdown]
# load the dataset that will drive our analysis.
#
# In this case, we are working with an insurance dataset that contains information about individuals such as
# `age, gender, BMI, number of children, smoking status, and region—along` with the corresponding insurance charges.
#
# We’ll load the data using **Pandas**
#
# Let’s load the dataset and take our first look at its structure.
#
# - The dataset file is named **`insurance_prediction`**.

# %% [markdown]
# ## connect to google drive

# %%
# uncomment and run the following line if using Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/rvs_genai_course/genai_projects/Health_Insurance_Prediction_ML/insurance_prediction.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_877/3950910149.py in <cell line: 0>()
# ----> 1 data = pd.read_csv('/content/drive/MyDrive/rvs_genai_course/genai_projects/Health_Insurance_Prediction_ML/insurance_prediction.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# Now that the dataset is loaded, it's important to understand its structure and content
#
#  This step involves:
#
# - Checking the number of rows and columns.
# - Viewing the first few records to get a sense of the data.
# - Identifying data types for each feature.
# - Detecting any potential missing values or anomalies.
#
# Gaining a clear overview helps us plan the necessary preprocessing steps and ensures we’re working with clean, well-structured data.
#
# Let’s explore the dataset and see what we’re working with.

# %% [markdown]
# **shape of the data (rows,coumns/dimension)**

# %%
data.shape
# Out:
# (1338, 7)

# %% [markdown]
# *  `1,338` rows
# *  `7` columns | Dimensions

# %%
data.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# The code provides a summary of the DataFrame, including the number of non-null entries, data types, and memory usage.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# - The dataset contains **7 columns** and **1338 rows**, with **no missing values**.
# - Data types are as expected:
#   - **Numeric:** `age`, `bmi`, `children`, `charges`
#   - **Categorical:** `sex`, `smoker`, `region`

# %% [markdown]
# **Dependent Variables** ( `Y` - Target Variable to be predicted )
# * **charges** (continuous values `numerical`)
#
# **Independent Variables** ( `X` - Feature Variable to be get patterns )
# * age (numerical)
# * bmi (numerical)   the normal BMI range is 18.5 to 24.9 kg/m².
# * children (numerical)
# * sex (categorical - bi)
# * smoker (categorical - bi)
# * region (categorical - multi)
#
# From this we can infer that
# > We are going to build an `Regression Model` - `Linear Regression`
#
# > Needs to be `encoded` for categorical variables

# %% [markdown]
# We conclude there are no missing rows in the DataFrame as all columns have 1338 non-null entries, matching the total number of records.

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# **Key Insights from Numerical Feature Summary:**
#
# *   **Age:**
#     *   Ranges from 18 to 64 years.
#     *   Average age is approximately 39 years.
#     *   A standard deviation of 14 suggests a wide age distribution.
#
# *   **BMI:**
#     *   Ranges from 15.96 to 53.13.
#     *   Average BMI is around 30.66, indicating the average individual is in the obese category.
#
# *   **Children:**
#     *   Ranges from 0 to 5 children.
#     *   The average number of children is about 1.
#     *   50% of individuals have 1 or fewer children.
#     *   with most having between **0 and 2 children**.
#
# *   **Charges:**
#     *   Ranges from $1,121.87  to  $63,770.43.
#     *   Average charge is $13,270.42.
#
#     *   A high standard deviation of $12,110.01 indicates significant variability in charges.

# %%
data.describe(include='object')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# 1. **Gender:** The dataset has a nearly balanced gender distribution, with **male** being slightly more frequent (676 out of 1338).
# 2. **Smoking Status:** **Non-smokers** dominate the dataset (1064 entries), which could impact charge predictions.
# 3. **Region:** The **southeast** region has the highest number of entries (364), making it the most represented geographic area.

# %% [markdown]
# ### Find Duplicate rows

# %%
# Identify duplicate rows
duplicate_rows = data[data.duplicated(keep=False)]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {len(duplicate_rows)}")

# Display the duplicate rows (optional)
duplicate_rows
# Out:
# Number of duplicate rows: 2
#      age   sex    bmi  children smoker     region    charges
# 195   19  male  30.59         0     no  northwest  1639.5631
# 581   19  male  30.59         0     no  northwest  1639.5631

# %% [markdown]
#  **Drop the duplicate rows.**

# %%
# Drop duplicate rows
data = data.drop_duplicates()

# Print the shape of the DataFrame after removing duplicates
print(f"Shape after removing duplicates: {data.shape}")
# Out:
# Shape after removing duplicates: (1337, 7)

# %% [markdown]
# There were originally 1,338 rows. After removing 1 duplicate record, the dataset now contains 1,337 records.

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
#  Exploratory Data Analysis (EDA). This step is crucial for uncovering hidden patterns and spotting.
#
# In this section, we will:
#
# - Analyze the distribution of numerical features like **age**, **BMI**, and **charges**.
# - Examine the balance of categorical features such as **sex**, **smoker**, **region**, and **children**.
# - Explore relationships between variables, especially those that may influence insurance charges.

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# <font size=3 color="navyblue"> Visualize the distribution of age in the data
#
# </font>

# %%
# Create a histogram of the 'age' column
plt.figure(figsize=(8, 6))  # Set the figure size
sns.histplot(data['age'], bins=20, color='red', edgecolor='black',kde=True) # Create histogram with 20 bins
plt.title('Distribution of Age') # Set the title of the histogram
plt.xlabel('Age') # Set the label for the x-axis
plt.ylabel('Frequency') # Set the label for the y-axis
plt.show() # Display the plot

# %% [markdown]
# **Observation**:
# - From the chart, we can see that the **higher number of individuals in the lower age brackets** — particularly those around **20 to 25 years old**.
# - This suggests that **younger individuals may be more aware of** or have greater access to **insurance** options.

# %% [markdown]
# <font size=3 color="navyblue">Visualize the distribution of gender in the data.
# </font>

# %%
# Check gender distribution to see if the data is balanced.
plt.figure(figsize=(6, 6))
sns.countplot(x='sex', data=data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observation**:
# - We can see that the gender distribution of the population is nearly balanced between males and females, suggesting equal interest in insurance across genders.

# %% [markdown]
# <font size=3 color="navyblue"> Visualize the distribution of BMI in the data.
# </font>

# %%
# Analyze how BMI varies across individuals to detect obesity trends.
plt.figure(figsize=(10, 6))
sns.histplot(data['bmi'], kde=True)#Kernel Density Estimation.
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Observations:**
# - The data shows that most of the population has a BMI concentrated around 30, as evidenced by the peak of the distribution curve near this value. The bell-shaped curve with a slight right skew suggests a general trend toward higher body mass, with a few individuals having significantly higher BMI values (above 45), indicating the presence of outliers.

# %% [markdown]
# <font size=3 color="navyblue"> Visualize the distribution of smokers in the data.
# </font>

# %%
# Visualize the distribution of smokers in the data.
plt.figure(figsize=(6, 6))
sns.countplot(x='smoker', data=data)
plt.title('Smoker Distribution')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations:**
# - The majority of the population appears to be non-smokers.
# - This indicates that smoking status could be a key factor in health insurance assessments.

# %% [markdown]
# <font size=3 color="navyblue">Visualize the distribution of regions in the data.
# </font>

# %%
# Visualize the distribution of regions in the data.
plt.figure(figsize=(8, 6))
sns.countplot(x='region', data=data)
plt.title('Distribution of Regions')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations:**
# - The regional distribution of individuals is relatively balanced, though the `southeast` has a slightly higher concentration. This suggests potential regional influences that may be important for targeted outreach or service planning.

# %% [markdown]
# <font size=3 color="navyblue">Visualize the distribution of insurance charges using a box plot.
# </font>

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='charges', data=data)
plt.title('Distribution of Insurance Charges')
plt.xlabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - The boxplot shows that **most insurance charges fall below approximately 20,000**, with the **median around 9,000**. However, there are a **significant number of outliers** beyond 35,000, indicating that some individuals incur **very high medical costs**. This right-skewed distribution suggests a need for special attention to these high-cost cases when building predictive models or setting premium strategies.

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# <font size=3 color="navyblue">Visualize how insurance charges vary with age.
# </font>

# %%
# Create a scatter plot to visualize the relationship between age and charges.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='charges', data=data)
plt.title('Charges vs. Age')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - Insurance charges generally rise with age, indicating a positive correlation where older individuals tend to incur higher costs.
# - The chart suggests the presence of three distinct clusters, possibly indicating different insurance plan

# %% [markdown]
# <font size=3 color="navyblue">Visualize how insurance charges vary with Smokers.
#
# </font>

# %%
# Compare charges for smokers vs. non-smokers
plt.figure(figsize=(10, 6))
sns.boxplot(x='smoker', y='charges', data=data)
plt.title('Insurance Charges by Smoker Status')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - The boxplot reveals a **significant difference in insurance charges between smokers and non-smokers**.
# - Smokers tend to incur **much higher medical charges**, with a median above 30,000, compared to non-smokers whose median is below 10,000.
# - Additionally, the **spread of charges is much wider** for smokers, indicating more variability and higher risk.
# - This strong contrast suggests that smoking status is a **critical factor** in determining insurance pricing.

# %% [markdown]
# <font size=3 color="navyblue">Visualize how insurance charges vary with Gender.
#
# </font>

# %%
# Analyze if gender affects charges.
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='charges', data=data)
plt.title('Insurance Charges by Gender')
plt.xlabel('Gender')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - The box plot shows that males generally face higher and more variable insurance charges than females, suggesting gender may influence insurance pricing.
# - This also prompts further investigation into whether other factors like **smoking status** or **BMI** are disproportionately associated with gender, which could be indirectly influencing the observed differences.

# %% [markdown]
# <font size=3 color="navyblue">Visualize insurance charges across genders (male vs. female), further distinguishing between smokers and non-smokers within each gender using an appropriate chart.
#
# </font>

# %% [markdown]
# Compare charges across sex (male and female) and differentiate between smokers and non-smokers within each gender.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='sex', y='charges', hue='smoker', data=data)
plt.title('Insurance Charges by Gender and Smoker Status')
plt.xlabel('Gender')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - **Smokers** (both male and female) clearly have **significantly higher insurance charges** compared to non-smokers.
# - Among **smokers**, **males** tend to have **slightly higher median charges** than females.
# - For **non-smokers**, the distribution is similar across genders, but **male non-smokers show slightly more variability** in charges.

# %% [markdown]
# We plot the pair plot to visually explore relationships between key numerical features and see how smoking status affects insurance charges, as we can see a noticeable gap in charges between smokers and non-smokers.

# %%
# Create the pair plot
sns.pairplot(data, vars=['age', 'bmi', 'charges'], hue='smoker')
plt.show()

# %% [markdown]
# **Observations:**
# - **Smokers vs Non-Smokers**:
#    Smokers (orange) have **significantly higher insurance charges** compared to non-smokers (blue), clearly visible in the `charges` vs `bmi` and `charges` vs `age` plots.
#
# - **BMI and Charges**:
#    There's a **positive trend** between BMI and charges, especially among smokers, indicating that higher BMI may lead to higher costs.
#
# - **Age and Charges**:
#    Insurance charges tend to **increase with age**, more prominently for smokers.
#
# - **Distributions**:
#    The age and BMI distributions are **similar across smoker categories**, but charges are **skewed higher for smokers**.

# %% [markdown]
# <font size=3 color="navyblue"> Visualize how insurance charges vary with No of Childrens.
# </font>

# %% [markdown]
# Examine if having more children increases insurance charges.

# %%
# Analyze if the number of children influences charges.
plt.figure(figsize=(10, 6))
sns.boxplot(x='children', y='charges', data=data)
plt.title('Insurance Charges by Number of Children')
plt.xlabel('Number of Children')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - The box plot suggests that insurance charges increase with one or two children but plateau with three or more, indicating a limited impact of family size beyond a certain point.

# %% [markdown]
# <font size=3 color="navyblue"> Visualize how insurance charges vary with regions.
# </font>

# %%
# Analyze regional differences in charges.
plt.figure(figsize=(12, 6))
sns.boxplot(x='region', y='charges', data=data)
plt.title('Insurance Charges by Region')
plt.xlabel('Region')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Observations:**
# - The boxplot shows that insurance charges are fairly consistent across regions, with **similar medians around 10,000**. However, the **Southeast region** stands out with the **widest spread (~15,000)** and a greater number of high-value outliers, suggesting more variability in charges there. Overall, region may not be a strong predictor of insurance cost, but the Southeast might warrant closer examination due to its higher dispersion.

# %% [markdown]
# We check the heatmap to interpret how strongly different features are related to the target variable and identify which factors may influence it the most.

# %% [markdown]
# This is a **correlation heatmap**, which shows how strongly numerical variables are related to each other.
#
# - The values range from **-1 to 1**:
#   - **1** means a **perfect positive relationship** (as one goes up, the other goes up).
#   - **0** means **no relationship**.
#   - **-1** means a **perfect negative relationship** (as one goes up, the other goes down).

# %%
# Create a correlation matrix for numerical features
numerical_cols = ['age', 'bmi', 'charges']
correlation_matrix = data[numerical_cols].corr()

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# **Observatios:**
#
# - **Age vs Charges (0.30)**:
#    There’s a **moderate positive correlation**. This means that as people get older, their insurance charges tend to increase.
#
# - **BMI vs Charges (0.20)**:
#    There’s a **weak positive correlation**. Higher BMI might lead to higher insurance charges, but the relationship isn't very strong.
#
# - **Age vs BMI (0.11)**:
#    Almost **no correlation** — a person’s age doesn't really tell us much about their BMI.

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# To begin, we aim to build a linear regression models:
#
# 1. Using **all variables**, including **categorical features**
#
# 2. we need to **encode**  Categorical variables into a numerical format.
#
#     Machine learning algorithms require numerical input,
#
#     categorical features  - (`sex`, `smoker`, or `region`)
#
#     Transformation Techniques `**one-hot encoding**` or `**dummy encoding**`.
#
#
# 3. we **split it into `training` and `testing sets`**.
#
#  Typically, **70–80%** of the data is used for training, while the remaining **20–30%** is used for testing.

# %% [markdown]
# ### Encode the Data

# %% [markdown]
# <font size=3 color="navyblue">Dummy encode the 'sex', 'smoker', and 'region' columns in the data using dtype=int
# </font>

# %% [markdown]
# **NOTE :** We use **dtype=int** in dummy encoding to guarantee that the output is numerical (0 and 1), as it may otherwise default to Boolean values (True and False).

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data = pd.get_dummies(data, columns=['sex', 'smoker', 'region'], drop_first=True, dtype=int) # drop_first = True because the features either o or 1 for each if other columns are set to 0 the one colume set to 1

# %% [markdown]
# We check the DataFrame to verify whether the data has been encoded correctly.

# %%
data.head(10)
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
# 5   31  25.740         0   3756.62160         0           0                 0
# 6   46  33.440         1   8240.58960         0           0                 0
# 7   37  27.740         3   7281.50560         0           0                 1
# 8   37  29.830         2   6406.41070         1           0                 0
# 9   60  25.840         0  28923.13692         0           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# ...

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# <font size=3 color="navyblue">Split the data into training and testing sets, using `Charges` as the dependent variable (`y`). Use 70% of the data for training and 30% for testing.
#
#
# </font>

# %%
# Split data into features (X) and target (y)
X = data.drop('charges', axis=1) # drop column
y = data['charges']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.columns
# Out:
# Index(['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northwest',
#        'region_southeast', 'region_southwest'],
#       dtype='object')

# %% [markdown]
# <font size=3 color="navyblue">Check the shape of the training and testing data.
# </font>

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (935, 8)
# X_test shape: (402, 8)
# y_train shape: (935,)
# y_test shape: (402,)

# %% [markdown]
# The training and testing datasets are properly split, with approximately 70% of the data used for training and 30% for testing.

# %% [markdown]
# # **Model Building**

# %% [markdown]
# First, we create a blank DataFrame to store the training and testing metrics of different models.

# %% [markdown]
# <font size=3 color="navyblue">Create a blank DataFrame named model_eval_results to store the performance results of different models on the training and testing sets.
# </font>

# %%
# prompt: Create a blank DataFrame named model_eval_results to store the performance results of different models on the training and testing sets.

model_eval_results = pd.DataFrame(columns=['Model', 'Train_MSE', 'Train_R2','Train_AMSE', 'Test_MSE', 'Test_R2','Test_AMSE'])

# %%
model_eval_results.head()
# Out:
# Empty DataFrame
# Columns: [Model, Train_MSE, Train_R2, Train_AMSE, Test_MSE, Test_R2, Test_AMSE]
# Index: []

# %% [markdown]
# ##Model - Single Featue Model (Age)

# %% [markdown]
# n the first model, we use only the age feature to demonstrate how simple linear regression works and how it performs.

# %%
# Define features (X) and target (y) for Model 1 (Age only)
X_train_m1 = X_train[['age']]
X_test_m1 = X_test[['age']]

# Initialize and train the Linear Regression model
model_1 = LinearRegression()
model_1.fit(X_train_m1, y_train)
# Out:
# LinearRegression()

# %%
print(f'Linear Regression Equation: Charges = {model_1.intercept_:.2f} + ({model_1.coef_[0]:.2f} * Age)')
# Out:
# Linear Regression Equation: Charges = 3718.81 + (238.82 * Age)

# %% [markdown]
# ### *Evaluation*

# %%
# prompt: Evaluate the model’s performance on both the training and testing data, add it to model_eval_results, and display the results

# Predict on training and testing data
y_train_pred_m1 = model_1.predict(X_train_m1)
y_test_pred_m1 = model_1.predict(X_test_m1)

# Calculate MSE and R2 for training data
train_mse_m1 = mean_squared_error(y_train, y_train_pred_m1)
train_r2_m1 = r2_score(y_train, y_train_pred_m1)
train_amse_m1 = mean_absolute_error(y_train, y_train_pred_m1)

# Calculate MSE and R2 for testing data
test_mse_m1 = mean_squared_error(y_test, y_test_pred_m1)
test_r2_m1 = r2_score(y_test, y_test_pred_m1)
test_amse_m1 = mean_absolute_error(y_test, y_test_pred_m1)


# Add results to the DataFrame
model_eval_results.loc[len(model_eval_results)] = ['Model 1 (Age Only)', train_mse_m1, train_r2_m1, train_amse_m1, test_mse_m1, test_r2_m1, test_amse_m1]

# Display the results
model_eval_results
# Out:
#                 Model     Train_MSE  Train_R2   Train_AMSE      Test_MSE  \
# 0  Model 1 (Age Only)  1.246248e+08  0.082229  8806.530424  1.545219e+08
#
#     Test_R2   Test_AMSE
# 0  0.096985  9342.77782

# %% [markdown]
# ## Model - Model With Two Variables (Age,BMI)

# %% [markdown]
# Train a linear regression model using age and BMI as features, and charges as the dependent column.

# %%
# Define features (X) and target (y) for Model 2 (Age and BMI)
X_train_m2 = X_train[['age', 'bmi']]
X_test_m2 = X_test[['age', 'bmi']]

# Initialize and train the Linear Regression model
model_2 = LinearRegression()
model_2.fit(X_train_m2, y_train)
# Out:
# LinearRegression()

# %%
print(f'Linear Regression Equation: Charges = {model_2.intercept_:.2f} + ({model_2.coef_[0]:.2f} * Age) + ({model_2.coef_[1]:.2f} * BMI)')
# Out:
# Linear Regression Equation: Charges = -3641.79 + (227.40 * Age) + (254.94 * BMI)

# %% [markdown]
# ### *Evaluation*

# %%
# prompt: Evaluate the model’s performance on both the training and testing data, add it to model_eval_results, and display the results.

# Predict on training and testing data
y_train_pred_m2 = model_2.predict(X_train_m2)
y_test_pred_m2 = model_2.predict(X_test_m2)

# Calculate MSE and R2 for training data
train_mse_m2 = mean_squared_error(y_train, y_train_pred_m2)
train_r2_m2 = r2_score(y_train, y_train_pred_m2)
train_amse_m2 = mean_absolute_error(y_train, y_train_pred_m2)


# Calculate MSE and R2 for testing data
test_mse_m2 = mean_squared_error(y_test, y_test_pred_m2)
test_r2_m2 = r2_score(y_test, y_test_pred_m2)
test_amse_m2 = mean_absolute_error(y_test, y_test_pred_m2)


# Add results to the DataFrame
model_eval_results.loc[len(model_eval_results)] = ['Model 2 (Age and BMI)', train_mse_m2, train_r2_m2, train_amse_m2, test_mse_m2, test_r2_m2, test_amse_m2]

# Display the results
model_eval_results
# Out:
#                    Model     Train_MSE  Train_R2   Train_AMSE      Test_MSE  \
# 0     Model 1 (Age Only)  1.246248e+08  0.082229  8806.530424  1.545219e+08
# 1  Model 2 (Age and BMI)  1.222942e+08  0.099392  8838.077614  1.471034e+08
#
#     Test_R2    Test_AMSE
# 0  0.096985  9342.777820
# 1  0.140338  9223.733547

# %% [markdown]
# ## Model - Linear Regression Model

# %% [markdown]
# Now, we use the whole dataset, including both numerical and categorical features, to build our multiple linear regression model, and see how the model performs with all available information.

# %% [markdown]
# <font size=3 color="navyblue">Train a linear regression model using all features, and charges as the dependent column.
#
#
# </font>

# %%
# Initialize and train the Linear Regression model on the whole data
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <font size=3 color="navyblue">Display the linear regression equation.
#
# </font>

# %%
# Construct the equation string
equation = f'Charges = {model_lr.intercept_:.2f}'
for i, col in enumerate(X_train.columns):
    equation += f' + ({model_lr.coef_[i]:.2f} * {col})'

print(f'Linear Regression Equation: {equation}')
# Out:
# Linear Regression Equation: Charges = -11516.78 + (251.25 * age) + (328.38 * bmi) + (522.16 * children) + (-111.91 * sex_male) + (22874.45 * smoker_yes) + (-465.75 * region_northwest) + (-936.10 * region_southeast) + (-765.58 * region_southwest)

# %% [markdown]
# ### Interpretation of the Linear Regression Equation
#
# The equation for predicting insurance charges is:
#
# `Charges = -11516.78 + (251.25 * age) + (328.38 * bmi) + (522.16 * children) + (-111.91 * sex_male) + (22874.45 * smoker_yes) + (-465.75 * region_northwest) + (-936.10 * region_southeast) + (-765.58 * region_southwest)`
#
# Here’s what each component signifies:
#
# *   **Intercept (-11516.78):** This is the baseline charge when all other variables (age, BMI, children, and all dummy variables for sex, smoker, and region) are zero.
#
# *   **`age` (251.25):** For every one-year increase in age, the insurance charge is predicted to increase by approximately **$251.25**, assuming all other factors remain constant.
#
# *   **`bmi` (328.38):** For every one-unit increase in BMI, the insurance charge is predicted to increase by approximately **$328.38**, holding all other variables constant.
#
# *   **`children` (522.16):** For each additional child, the insurance charge is predicted to increase by approximately **$522.16**, with all other factors being equal.
#
# *   **`sex_male` (-111.91):** Being male (compared to female, which is the baseline for `sex`) is associated with a predicted **decrease of $111.91** in insurance charges, assuming all other variables are constant.
#
# *   **`smoker_yes` (22874.45):** Being a smoker (compared to a non-smoker) is associated with a very significant predicted **increase of $22,874.45** in insurance charges, assuming all other factors are constant. This highlights the substantial impact of smoking on insurance costs.
#
# *   **`region_northwest` (-465.75):** Being in the 'northwest' region (compared to the 'northeast' region, which is the baseline) is associated with a predicted **decrease of $465.75** in insurance charges.
#
# *   **`region_southeast` (-936.10):** Being in the 'southeast' region is associated with a predicted **decrease of $936.10** in insurance charges compared to the 'northeast'.
#
# *   **`region_southwest` (-765.58):** Being in the 'southwest' region is associated with a predicted **decrease of $765.58** in insurance charges compared to the 'northeast'.

# %% [markdown]
# <font size=3 color="navyblue">Evaluate the model’s performance on both the training and testing data, add it to model_eval_results, and display the results.
#
# </font>

# %%
# prompt: Evaluate the model’s performance on both the training and testing data, add it to model_eval_results, and display the results.

# Predict on training and testing data
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

# Calculate MSE and R2 for training data
train_mse = mean_squared_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)
train_amse = mean_absolute_error(y_train, y_train_pred)

# Calculate MSE and R2 for testing data
test_mse = mean_squared_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)
test_amse = mean_absolute_error(y_test, y_test_pred)

# Add results to the DataFrame
model_eval_results.loc[len(model_eval_results)] = ['Model_lr', train_mse, train_r2,train_amse, test_mse, test_r2, test_amse]

# Display the results
model_eval_results
# Out:
#                    Model     Train_MSE  Train_R2   Train_AMSE      Test_MSE  \
# 0     Model 1 (Age Only)  1.246248e+08  0.082229  8806.530424  1.545219e+08
# 1  Model 2 (Age and BMI)  1.222942e+08  0.099392  8838.077614  1.471034e+08
# 2               Model_lr  3.581293e+07  0.736264  4165.830851  3.894017e+07
#
#     Test_R2    Test_AMSE
# 0  0.096985  9342.777820
# 1  0.140338  9223.733547
# 2  0.772436  4181.815957

# %% [markdown]
# - The training and testing R-squared values are close (0.736 and 0.772), with MSE values similarly close, indicating the model is generalizing well, **not overfitting**, and performing well on unseen data.

# %%
train_r2_percent = model_eval_results['Train_R2'].iloc[0] * 100
test_r2_percent = model_eval_results['Test_R2'].iloc[0] * 100

print(f"Training R-squared: {train_r2_percent:.2f}%")
print(f"Testing R-squared: {test_r2_percent:.2f}%")
# Out:
# Training R-squared: 8.22%
# Testing R-squared: 9.70%

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=y_train, y=y_train_pred, alpha=0.6)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'r--', lw=2)
plt.title('Actual vs. Predicted Charges for Linear Regression Model for train fit')
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=y_test, y=y_test_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title('Actual vs. Predicted Charges for Linear Regression Model')
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.show()

# %% [markdown]
# ## Model - Random Forest Regression

# %% [markdown]
# <center>
#   <img src="https://drive.google.com/uc?export=view&id=10UNppEcSYr6p6LC8ekSpA3jdclnDG_7a" alt="Description">
# </center>

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize and train the Random Forest Regressor model
model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(X_train, y_train)

# Predict on training and testing data
y_train_pred_rf = model_rf.predict(X_train)
y_test_pred_rf = model_rf.predict(X_test)

# Calculate MSE, R2, and MAE for training data
train_mse_rf = mean_squared_error(y_train, y_train_pred_rf)
train_r2_rf = r2_score(y_train, y_train_pred_rf)
train_amse_rf = mean_absolute_error(y_train, y_train_pred_rf)

# Calculate MSE, R2, and MAE for testing data
test_mse_rf = mean_squared_error(y_test, y_test_pred_rf)
test_r2_rf = r2_score(y_test, y_test_pred_rf)
test_amse_rf = mean_absolute_error(y_test, y_test_pred_rf)

# Add results to the DataFrame
model_eval_results.loc[len(model_eval_results)] = ['RandomForest', train_mse_rf, train_r2_rf, train_amse_rf, test_mse_rf, test_r2_rf, test_amse_rf]

# Display the updated results
display(model_eval_results)
# Out:
#                    Model     Train_MSE  Train_R2   Train_AMSE      Test_MSE  \
# 0     Model 1 (Age Only)  1.246248e+08  0.082229  8806.530424  1.545219e+08
# 1  Model 2 (Age and BMI)  1.222942e+08  0.099392  8838.077614  1.471034e+08
# 2               Model_lr  3.581293e+07  0.736264  4165.830851  3.894017e+07
# 3           RandomForest  3.522529e+06  0.974059  1044.321534  2.334243e+07
#
#     Test_R2    Test_AMSE
# 0  0.096985  9342.777820
# 1  0.140338  9223.733547
# 2  0.772436  4181.815957
# 3  0.863588  2633.182105

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(x=y_test, y=y_test_pred_rf, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title('Actual vs. Predicted Charges for Linear Regression Model')
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# --- Polynomial Regression Model ---
# Define the degree of the polynomial
degree = 2  # You can change this degree as needed

# Create Polynomial Features
poly_features = PolynomialFeatures(degree=degree)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Initialize and train the Linear Regression model with polynomial features
model_poly_lr = LinearRegression()
model_poly_lr.fit(X_train_poly, y_train)

# Predict on training and testing data
y_train_pred_poly_lr = model_poly_lr.predict(X_train_poly)
y_test_pred_poly_lr = model_poly_lr.predict(X_test_poly)

# Calculate MSE, R2, and MAE for training data
train_mse_poly_lr = mean_squared_error(y_train, y_train_pred_poly_lr)
train_r2_poly_lr = r2_score(y_train, y_train_pred_poly_lr)
train_amse_poly_lr = mean_absolute_error(y_train, y_train_pred_poly_lr)

# Calculate MSE, R2, and MAE for testing data
test_mse_poly_lr = mean_squared_error(y_test, y_test_pred_poly_lr)
test_r2_poly_lr = r2_score(y_test, y_test_pred_poly_lr)
test_amse_poly_lr = mean_absolute_error(y_test, y_test_pred_poly_lr)

# Add results to the DataFrame
model_eval_results.loc[len(model_eval_results)] = [f'Polynomial_LR (Degree {degree})', train_mse_poly_lr, train_r2_poly_lr, train_amse_poly_lr, test_mse_poly_lr, test_r2_poly_lr, test_amse_poly_lr]

# Display the updated results
display(model_eval_results)

# Plot actual vs. predicted for test set
plt.figure(figsize=(10, 7))
sns.scatterplot(x=y_test, y=y_test_pred_poly_lr, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f'Actual vs. Predicted Charges for Polynomial Regression (Degree {degree})')
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.show()
# Out:
#                       Model     Train_MSE  Train_R2   Train_AMSE  \
# 0        Model 1 (Age Only)  1.246248e+08  0.082229  8806.530424
# 1     Model 2 (Age and BMI)  1.222942e+08  0.099392  8838.077614
# 2                  Model_lr  3.581293e+07  0.736264  4165.830851
# 3              RandomForest  3.522529e+06  0.974059  1044.321534
# 4  Polynomial_LR (Degree 2)  2.133331e+07  0.842896  2813.552037
#
#        Test_MSE   Test_R2    Test_AMSE
# 0  1.545219e+08  0.096985  9342.777820
# 1  1.471034e+08  0.140338  9223.733547
# 2  3.894017e+07  0.772436  4181.815957
# 3  2.334243e+07  0.863588  2633.182105
# 4  2.553477e+07  0.850777  2940.823435

# %% [markdown]
# # **Business Recommendation**

# %% [markdown]
# 1. **Targeted Premium Adjustments**
#    - Implement tiered pricing based on **age** and **BMI** to reflect varying risk levels more accurately.
#
# 2. **Smoking Cessation Incentives**
#    - Given the significant impact of smoking on insurance costs, consider offering discounts or wellness incentives to support non-smoking behavior and encourage a broader base of lower-risk customers.
#
# 3. **Wellness Programs**
#    - Introduce health programs to help policyholders manage BMI, which could lower both their charges and the company’s risk exposure.
#
# 4. **Region-Specific Strategies**
#    - Explore regional pricing only if operational costs or risk profiles justify it; otherwise, standard pricing may suffice.
#
# 5. **Marketing Focus**
#    - Target low-risk demographics—such as younger individuals, non-smokers, and those with healthy BMI—for affordable premium plans, while offering personalized support and coverage options for higher-risk segments.

# %% [markdown]
# # Predicting by passing a Value

# %% [markdown]
# ### First make a prediction with existing Dataframe row

# %%
X_train.head(1)
# Out:
#      age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 138   54  31.9         3         0           0                 0
#
#      region_southeast  region_southwest
# 138                 1                 0

# %% [markdown]
# * age = 54
# * bmi = 31.9
# * children = 3
# * sex = female
# * smoker = no
# * region = southwest

# %%
data_to_pred = X_train.head(1)

res = model_lr.predict(data_to_pred)

print(round(res[0],2))
# Out:
# 13156.3

# %% [markdown]
# ## Predicting for unseen data

# %% [markdown]
# ## Input Coulmns : `age	sex	bmi	children	smoker	region`
# ## Feature To Be Predicted : `charges`

# %%
#For Getting Input from user

# age = int(input("Enter the age: "))
# sex = input("Enter the sex (male/female): ")
# bmi = float(input("Enter the BMI: "))
# children = int(input("Enter the number of children: "))
# smoker = input("Enter the smoking status (yes/no): ")
# region = input("Enter the region (southeast/southwest/northeast/northwest): ")

def get_input_df(df_new, age, sex, bmi, children, smoker, region):

    df_new.loc[0, 'age'] = age
    df_new.loc[0, 'sex_male'] = 1 if sex.lower() == 'male' else 0
    df_new.loc[0, 'bmi'] = bmi
    df_new.loc[0, 'children'] = children
    df_new.loc[0, 'smoker_yes'] = 1 if smoker.lower() == 'yes' else 0
    df_new.loc[0, 'region_northwest'] = 1 if region.lower() == 'northwest' else 0
    df_new.loc[0, 'region_southwest'] = 1 if region.lower() == 'southwest' else 0
    df_new.loc[0, 'region_southeast'] = 1 if region.lower() == 'southeast' else 0


df_new = pd.DataFrame(columns=['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest'])

get_input_df(df_new, 54, 'female', 31.9, 3, 'no', 'southwest')

#prediction

data_to_pred = df_new.head(1)

res = model_lr.predict(data_to_pred)

print("Prepared input DataFrame for prediction:")
display(df_new.head())

print(f"\nPredicted charges for the input: {res[0]:.2f}")
# Out:
# Prepared input DataFrame for prediction:
#   age   bmi children sex_male smoker_yes region_northwest region_southeast  \
# 0  54  31.9        3        0          0                0                0
#
#   region_southwest
# 0                1
# Predicted charges for the input: 13326.82

# %% [markdown]
# # Save the developed model

# %%
import joblib

# Save the model to a file
joblib.dump(model_lr, '/content/drive/MyDrive/rvs_genai_course/genai_projects/Health_Insurance_Prediction_ML/linear_regression_model.joblib')

print("Model saved successfully as 'linear_regression_model.joblib'")
# Out:
# Model saved successfully as 'linear_regression_model.joblib'

# %% [markdown]
# .h5 file - HDF5 format
#
# While `.h5` files (HDF5 format) are excellent for storing **large numerical datasets** and are very commonly used for deep learning models (like those built with Keras or TensorFlow)
#
# because they can efficiently save the model architecture, weights, and optimizer state, they are not the standard for scikit-learn models like `LinearRegression` or `RandomForestRegressor`.
#
# For scikit-learn models, `joblib` (or pickle) is the preferred method because these models are typically composed of `Python objects and NumPy arrays`.
#
# joblib is optimized for handling these kinds of objects efficiently, especially when they contain `large arrays`.
#
#  It serializes the entire Python object, including the model's internal state, making it straightforward to load and use the model directly
#
# So, in this case, `joblib.dump()` is the most appropriate and common way to save your LinearRegression model.

# %% [markdown]
# # <center>The End</center>

# %%
import joblib
import pandas as pd
from google.colab import drive

# 1. Mount Google Drive
drive.mount('/content/drive')

# Define the path to your saved model
model_path = '/content/drive/MyDrive/rvs_genai_course/genai_projects/Health_Insurance_Prediction_ML/linear_regression_model.joblib'

# 2. Load the model
try:
    loaded_model = joblib.load(model_path)
    print("Model loaded successfully!")
except FileNotFoundError:
    print(f"Error: Model file not found at {model_path}. Please check the path and ensure Drive is mounted.")
    # Exit or handle the error appropriately
    exit()

# 3. Prepare new input data for prediction
# This DataFrame must have the same columns and order as X_train during training.
# Based on X.columns in the notebook: ['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest']

# Example new data for a male, 30 years old, BMI 25, 1 child, non-smoker, in the northeast region
# For categorical features, remember the one-hot encoding logic used (e.g., sex_male = 1 for male, 0 for female)
# And 'northeast' was the baseline region, so its dummy variables would all be 0.

new_data_features = {
    'age': 30,
    'bmi': 25.0,
    'children': 1,
    'sex_male': 1,  # 1 for male, 0 for female
    'smoker_yes': 0, # 1 for smoker 'yes', 0 for 'no'
    'region_northwest': 0, # 1 for northwest, 0 otherwise
    'region_southeast': 0, # 1 for southeast, 0 otherwise
    'region_southwest': 0  # 1 for southwest, 0 otherwise
}

# Create a DataFrame from the new data
new_data_df = pd.DataFrame([new_data_features])

print("\nNew input data for prediction:")
display(new_data_df)

# 4. Make a prediction
prediction = loaded_model.predict(new_data_df)

print(f"\nPredicted insurance charges for the new data: ${prediction[0]:.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model loaded successfully!
#
# New input data for prediction:
#    age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   30  25.0         1         1           0                 0
#
#    region_southeast  region_southwest
# 0                 0                 0
# Predicted insurance charges for the new data: $4640.43
